# %%
import pandas as pd

df = pd.read_csv("data/ALLBIRDTRAITS_Database_March_2026.csv")
df["ResearchEffort"].min()
# Out:
# np.int64(0)

# %%
df["HabitatBreadth"].hist()
# Out:
# <Axes: >

# %%
df[df["Family"] == "ANATIDAE"]
# Out:
#     Unnamed: 0         Order    Family      Genus               Species  \
# 13        3434  ANSERIFORMES  ANATIDAE       Anas            Anas_acuta
# 14        3468  ANSERIFORMES  ANATIDAE     Aythya         Aythya_ferina
# 15        3469  ANSERIFORMES  ANATIDAE     Aythya         Aythya_marila
# 18        3562  ANSERIFORMES  ANATIDAE   Clangula     Clangula_hyemalis
# 38        4373  ANSERIFORMES  ANATIDAE       Anas    Anas_platyrhynchos
# 39        4374  ANSERIFORMES  ANATIDAE      Anser           Anser_anser
# 40        4375  ANSERIFORMES  ANATIDAE      Anser  Anser_brachyrhynchus
# 42        4436  ANSERIFORMES  ANATIDAE     Cygnus           Cygnus_olor
# 63        7446  ANSERIFORMES  ANATIDAE     Aythya       Aythya_fuligula
# 64        7450  ANSERIFORMES  ANATIDAE  Bucephala    Bucephala_clangula
# 78        8544  ANSERIFORMES  ANATIDAE     Cygnus    Cygnus_columbianus
# 79        8584  ANSERIFORMES  ANATIDAE      Netta          Netta_rufina
#
# ...
